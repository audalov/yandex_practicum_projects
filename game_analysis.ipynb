# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <b>🥇 Александр, спасибо за доработки, проект принят, молодец!</b>
#
# Ты провел очень хорошую работу над ошибками! Уверен, ты обязательно достигнешь своей цели! Успехов в дальнейшем обучении! 🙂

# %% [markdown]
# Александр, привет! Меня зовут Ефимов Денис и сегодня я буду делать ревью твоего проекта!\
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Если все сделано хорошо. </div>
#
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b> Некритичное замечание; если таких замечаний меньше трех — проект может быть принят без их отработки.</div>
#
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b> Грубая ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Hello World! ✔
# </div>
#
# Или можешь использовать эту галочку ✔ в моих комментариях, если писать особо нечего.
#
# <div class="alert alert-block alert-warning">
# <b>Общее впечатление:</b>
#
# - Ты проделал огромную работу и проект получился впечатляющим:)
# - У меня есть несколько замечаний, исправив которые ты сделаешь проект еще лучше.
# - Пробегись по моим комментариям, исправь недочёты и всё будет отлично :)
#
# </div>

# %% [markdown]
# # Сборный проект: определение закономерностей, определяющие успешность компьютерной игры.

# %% [markdown]
# # Вводная часть
#
# **Цель:** на основе данных, представленных на конец 2016 года, подготовить прогноз успешности компьютерной игры в зависимости от жанра, региона, платформы и возрастного цензора.
#
# **Представленные данные:**
#    - **Name** — название игры;
#    - **Platform** — платформа;
#    - **Year_of_Release** — год выпуска;
#    - **Genre** — жанр игры;
#    - **NA_sales** — продажи в Северной Америке *(миллионы проданных копий)*;
#    - **EU_sales** — продажи в Европе *(миллионы проданных копий)*;
#    - **JP_sales** — продажи в Японии *(миллионы проданных копий)*;
#    - **Other_sales** — продажи в других странах *(миллионы проданных копий)*;
#    - **Critic_Score** — оценка критиков *(максимум 100)*;
#    - **User_Score** — оценка пользователей *(максимум 10)*;
#    - **Rating** — рейтинг от организации ESRB.
#
# **План работ:**
#
# 1. **Ознакомление с массивом данных** *(общая информация)*.
#
#
# 2. **Предобработка данных**:
# - приведение наименования столбцов в нижний регистр;
# - поиск дубликатов и их удаление;
# - поиск пропущенных значений и их заполнение *(удаление при невозможности)*;
# - рассчет суммарных продаж во всех регионах.
#
#
# 3. **Исследовательский анализ данных**:
# - распределение выпуска игр в зависимости от года;
# - распределение продаж в зависимостио от платформы;
# - определение актуального периода для построение прогноза на 2017 год;
# - определение наиболее прибыльных платформы на ближайшие годы;
# - влияние отзывов пользователей и критиков на динамику продаж игр;
# - соотношение жанра игр и уровнем их продаж.
#
# 4. **Составление портрета идеального пользователя**:
# - определение топ-5 платформ;
# - определение топ-5 жанров;
# - зависимость продаж от рейтинга для каждого региона.
#
# 5. **Проверка гиптоез**:
# - средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - средние пользовательские рейтинги жанров Action и Sports разные.
#
# 6. **Итоговый вывод и рекомендации**.

# %% [markdown]
# # Памятка. Создаваемые датафреймы.
#
# 1. **data** - исходный датафрейм;
# 2. **data_platform** - сводный датафрейм иллюстрирующий суммарные продажи по платформам;
# 3. **data_top_sales** - сводный датафрейм иллюстрирующий продажи в зависимости от платформы и года;
# 4. **time_of_life** - сводный датафрейм иллюстрирующий средний уровень жизни платформы;
# 5. **data_actual** - исходный датафрейм ограниченный по году (начало берем с 2013);
# 6. **data_actual_sum** - сводный датафрейм иллюстрирующий суммарные продажи по платформам для актуального периода;
# 7. **data_actual_top** - сводный датафрейм иллюстрирующий продажи в зависимости от платформы и года для актуального периода;
# 8. **data_actual_region** - сводный датафрейм иллюстрирующий показатели продаж игр и долю этих продаж в зависимости от платформы по регионам;
# 9. **data_actual_genre** - сводный датафрейм иллюстрирующий показатели продаж игр и долю этих продаж в зависимости от жанра по регионам;
# 9. **data_ESRB** - сведенный датафрейм из значений, определяющий зависимость продаж в Северной Америке от рейтинга ESRB;
# 10. **data_actual_XOne_PC и data_actual_Action_Sports** - датафреймы для проверки гипотез.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец, что написал введение!  </div>

# %% [markdown]
# ## Изучение общей информации о представленных данных.

# %% [markdown]
# ### Импорт необходимых библиотек

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import seaborn as sns
from scipy import stats as st
import numpy as np

# %% [markdown]
# ### Ознакомление с представленными данными

# %%
data = pd.read_csv('/datasets/games.csv')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# ### **Вывод по первому пункту**
#
# При первом ознакомлении с представленными данными:
# 1. Датафрейм представляет из себя массив данных, включающий 11 столбцов и 16715 строк.
# 2. Необходимо наименование всех столбцов перевести в нижний регистр.
# 3. Присутствуют незначительные пропуски в столбцах: **name, year_of_release, genre**.
# 4. Присутствуют существенные пропуски в столбцах: **critic_score, user_score, reating**.
# 5. Столбцы **year_of_release, user_score** необходимо привести к нужному типу.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Отлично, с данными познакомились!  </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Посчитаем для начала количество пропусков.

# %%
data.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# **Пропуски присутствуют в 6 из 11 столбцах**

# %% [markdown]
# ### Перевод в нижний регистр

# %%
data.columns = data.columns.str.lower()

# %% [markdown]
# ### Преобразование в нужный тип данных

# %%
print(f"Доля строк с пропущенными значениями стобца year_of_release: {(data['year_of_release'].isnull().sum() / len(data)):.2%}")
# Out:
# Доля строк с пропущенными значениями стобца year_of_release: 1.61%

# %% [markdown]
# **Незначительная доля пропусков**. Скорее всего они являются полностью случайными, т.е. независят ни как от данных.
#
# Удалим их для дальнейших расчетов.

# %%
data = data.dropna(subset = ['year_of_release']) 
data['year_of_release'] = data['year_of_release'].astype('int') # приводим тип столбца в int

# %% [markdown]
# **Посмотрим на уникальные значения в столбцах user_score и critic score**

# %%
print(data['user_score'].unique())
print(data['critic_score'].unique())
# Out:
# ['8' nan '8.3' '8.5' '6.6' '8.4' '8.6' '7.7' '6.3' '7.4' '8.2' '9' '7.9'
#  '8.1' '8.7' '7.1' '3.4' '5.3' '4.8' '3.2' '8.9' '6.4' '7.8' '7.5' '2.6'
#  '7.2' '9.2' '7' '7.3' '4.3' '7.6' '5.7' '5' '9.1' '6.5' 'tbd' '8.8' '6.9'
#  '9.4' '6.8' '6.1' '6.7' '5.4' '4' '4.9' '4.5' '9.3' '6.2' '4.2' '6' '3.7'
#  '4.1' '5.8' '5.6' '5.5' '4.4' '4.6' '5.9' '3.9' '3.1' '2.9' '5.2' '3.3'
#  '4.7' '5.1' '3.5' '2.5' '1.9' '3' '2.7' '2.2' '2' '9.5' '2.1' '3.6' '2.8'
#  '1.8' '3.8' '0' '1.6' '9.6' '2.4' '1.7' '1.1' '0.3' '1.5' '0.7' '1.2'
#  '2.3' '0.5' '1.3' '0.2' '0.6' '1.4' '0.9' '1' '9.7']
# [76. nan 82. 80. 89. 58. 87. 91. 61. 97. 95. 77. 88. 83. 94. 93. 85. 86.
#  98. 96. 90. 84. 73. 74. 78. 92. 71. 72. 68. 62. 49. 67. 81. 66. 56. 79.
#  70. 59. 64. 75. 60. 63. 69. 50. 25. 42. 44. 55. 48. 57. 29. 47. 65. 54.
#  20. 53. 37. 38. 33. 52. 30. 32. 43. 45. 51. 40. 46. 39. 34. 41. 36. 31.
#  27. 35. 26. 19. 28. 23. 24. 21. 17. 13.]

# %% [markdown]
# Характеристика столбца *user_score*:
# - имеются пропущенные значения (nan);
# - имеются значения с формулировкой **tbd**: рейтинг либо еще не определен, либо издатель игры отказался от рейтинга;
# - необходимо преобразовать тип в float.
#
# Характеристика столбца *critic_score*:
# - имеются пропущенные значения (nan);
# - есть смысл преобразовать в int, т.к. отсутсвуют дробные значения.

# %%
tbd_count = data.loc[data['user_score'] == 'tbd']['user_score'].count()
total_count = len(data)
percentage = tbd_count / total_count

output = (
    f"Количество ячеек со значением tbd: {tbd_count} "
    f"(доля от общего массива: {percentage:.2%})"
)

print(output)
# Out:
# Количество ячеек со значением tbd: 2376 (доля от общего массива: 14.45%)

# %% [markdown]
# Доля ячеек со значением **tbd** высокая, удалять нельзя.
#
# **Заменим tbd на "-1"**, что бы исключить искажение данных в последующих рассчетах.

# %%
data.loc[data['user_score'] == 'tbd', 'user_score'] = -1 # заменил tbd на -1

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Главное не забывать потом эти значения перед расчетами отфильтровывать) </div>

# %% [markdown]
# **Посчитаем количество и долю пропущенных значений в столбцах *user_score* и *critic_score***

# %%
def print_missing_values_count(column_name, column_label):
    isnull_count = data[column_name].isnull().sum()
    total_count = len(data)
    percentage = isnull_count / total_count
    output = f"Количество ячеек с пропущенными значениями в столбце '{column_label}': {isnull_count} (доля от общего массива: {percentage:.2%})"
    print(output)

print_missing_values_count('user_score', 'user_score')
print_missing_values_count('critic_score', 'critic_score')
# Out:
# Количество ячеек с пропущенными значениями в столбце 'user_score': 6607 (доля от общего массива: 40.17%)
# Количество ячеек с пропущенными значениями в столбце 'critic_score': 8463 (доля от общего массива: 51.46%)

# %% [markdown]
# Пропущенных значений в столбцах user_score и critic_score много.
#
# **Построим график пропусков по годам.** Есть предпоположения, что до определенного года оценок просто небыло.

# %%
missing_percentage_user_score = data.groupby('year_of_release')['user_score'].apply(lambda x: x.isnull().mean())
missing_percentage_critic_score = data.groupby('year_of_release')['critic_score'].apply(lambda x: x.isnull().mean())

total_records = data['year_of_release'].value_counts()

plt.style.use('seaborn-darkgrid')

fig, ax = plt.subplots(figsize=(18, 6))

ax.bar(missing_percentage_user_score.index, missing_percentage_user_score, width=0.4, label='Доля пропусков user_score', color='tan', align='center')
ax.bar(missing_percentage_critic_score.index + 0.4, missing_percentage_critic_score, width=0.4, label='Доля пропусков critic_score', color='purple', align='center')
ax.set_xlabel('Год выпуска', fontsize=12)
ax.set_ylabel('Доля пропусков', fontsize=12)
ax.set_title('Доля пропусков пользовательских оценок и оценок критиков', fontsize=16, fontweight='bold')
ax.legend(fontsize=10)
ax.grid(axis='y', linestyle='--', linewidth=0.5)

ax.set_xticks(missing_percentage_user_score.index)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Из графика видно:**
# 1. До 1995 года системы оценики критиков и пользователей небыло *(заисключением пары годов)*
# 2. в 2000 году система оценок принимает широкое распространение.
# 3. После 2005 наблюдается рост пропусков, здесь есть несколько вариантов:
#    - производители игры просто отказывались от участия в рейтинговых опросах;
#    - пропуски связаны с тем, что оценка выставлялась для игры только на одной платформе;
#    - случайные пропуски по независмым от нас причинам.
#
# **План действий:**
# 1. Все пропуски до 1995 года заменяем на -1 *(условная заглушка)*.
# 2. Пропуски с 1995 по 2016 год пробуем заменить в зависимости от наименования игры.
# 3. Остальные пропуски заполняем так же -1.

# %% [markdown]
# **Заменим пропуски до 1995 года на -1**

# %%
data.loc[data['year_of_release'] < 1995, 'user_score'] = data['user_score'].fillna(-1)

# %% [markdown]
# **Пропуски с 1995 по 2016 год проубем заменить в зависимости от наименования игры**
#
# *(предварительно переведем все наименования игр в нижний регистр)*

# %%
data['name'] = data['name'].str.lower()

#data['user_score'] = pd.to_numeric(data['user_score'], errors='coerce')
#data['critic_score'] = pd.to_numeric(data['critic_score'], errors='coerce')

#average_user_scores = data.groupby('name')['user_score'].transform('mean')
#average_critic_scores = data.groupby('name')['critic_score'].transform('mean')

#data['user_score'] = data['user_score'].fillna(average_user_scores)
#data['critic_score'] = data['critic_score'].fillna(average_critic_scores)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Заполнять пропуски в оценках неверное решение) Ошибка связана с тем, что данные по оценкам не являются набором случайных наблюдений. Если бы у нас была выборка всех оценок пользователей для одной игры (один пользователь поставил оценку 10, другой 1, третий 5), то пропуски мы могли бы заменить медианой.
#
# В нашем случае оценка уже является усредненным значением выборки оценок некоторого количества пользователей. Более того, можно найти примеры, когда оценки одной игры на различных платформах отличаются в два раза.
#
# Аналогичная ситуация и с рейтингами критиков.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Закоментил замену пропусков на медианные значения, оставил только заглушку.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Посчитаем теперь долю пропущенных значений**

# %%
#def print_missing_values_count(column_name, column_label):
    #isnull_count = data[column_name].isnull().sum()
    #total_count = len(data)
    #percentage = isnull_count / total_count
    #output = f"Количество ячеек с пропущенными значениями в столбце '{column_label}': {isnull_count} (доля от общего массива: {percentage:.2%})"
    #print(output)

#print_missing_values_count('user_score', 'user_score')
#print_missing_values_count('critic_score', 'critic_score')

# %%
data['user_score'] = data['user_score'].fillna(-1)
data['critic_score'] = data['critic_score'].fillna(-1)

# %% [markdown]
# **Теперь можем перевести в нужный тип данных**

# %%
data['user_score'] = data['user_score'].astype('float') 
data['critic_score'] = data['critic_score'].astype('int')

# %% [markdown]
# ### Поиск и замена пропущенных значений

# %% [markdown]
# **Предварительно мы уже избавились от пропуской в трех столбцах: *user_score*, *critic_score*, *year_of_release***

# %%
data.isnull().sum()
# Out:
# name                  2
# platform              0
# year_of_release       0
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score          0
# user_score            0
# rating             6678
# dtype: int64

# %% [markdown]
# **Пропуски остались в трех столбцах:**
# 1. name - 2 пропуска, предлагается удалить *(вероятно это полностью случайный пропуск)*
# 2. genre - 2 пропуска, предлагается удалить *(вероятно это полностью случайный пропуск)*
# 3. Пропуски в столбце rating существенные:
#    - заменим их на TBD, потому что организация ESRB ведет свою деятельность только в США и Канаде.

# %%
data = data.dropna(subset = ['name', 'genre'])

# %%
data = data.dropna(subset = ['name', 'genre'])

data['rating'] = data['rating'].fillna('TBD') 

print(f'Итоговое количество строк с пропускам: {data.isnull().sum().sum()}')
# Out:
# Итоговое количество строк с пропускам: 0

# %% [markdown]
# **Пропуски все заполнены**

# %% [markdown]
# ### Поиск дубликатов

# %% [markdown]
# **Определим явные дубликаты.**

# %%
print(f'Количесто дублирующих строк: {data.duplicated().sum()}')
# Out:
# Количесто дублирующих строк: 0

# %% [markdown]
# **Явных дубликатов нет.**
#
# Проверим дубликаты на основании двух столбцов: **name и platform.**

# %%
duplicate_count = data.duplicated(subset=['name', 'platform'], keep=False).sum()

print("Количество строк, в которых дублируются и название игры, и платформа:", duplicate_count)
# Out:
# Количество строк, в которых дублируются и название игры, и платформа: 6

# %% [markdown]
# **Таких строк оказалось немного. Посмотрим на них.**

# %%
duplicate_rows = data[data.duplicated(subset=['name', 'platform'], keep=False)]
duplicate_rows
# Out:
#                               name platform  year_of_release   genre  \
# 604                  madden nfl 13      PS3             2012  Sports
# 1190   need for speed: most wanted     X360             2012  Racing
# 1591   need for speed: most wanted     X360             2005  Racing
# 5972   need for speed: most wanted       PC             2005  Racing
# 11715  need for speed: most wanted       PC             2012  Racing
# 16230                madden nfl 13      PS3             2012  Sports
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 604        2.11      0.22      0.00         0.23            83         5.5
# 1190       0.62      0.78      0.01         0.15            83         8.5
# 1591       1.00      0.13      0.02         0.10            83         8.5
# 5972       0.02      0.23      0.00         0.04            82         8.5
# 11715      0.00      0.06      0.00         0.02            82         8.5
# ...

# %% [markdown]
# **Гипотеза не подтведилась.** По сути дублирующей оказалась только одна игра: madden nfl 13 - удалим дубликат, раз нашли его.
#
# Ned for speed хоть имеет и одинаковое название, и платформу - отличается годом выпуска.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Здорово, что сделал такую проверку!  </div>

# %%
data = data.drop(16230, axis=0)

data = data.reset_index(drop=True)

# %% [markdown]
# **Проверим неявные дубликаты в столбце genre и platform**

# %%
print(data['genre'].unique())
print(data['platform'].unique())
# Out:
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']

# %% [markdown]
# **Неявные дубликаты отсутсвуют.**

# %% [markdown]
# ### Подсчет суммарных продаж

# %%
data['sum_sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# перенес действие из пункта 3.2, применил метод DataFrame.sum
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> 👍  </div>

# %% [markdown]
# ### **Вывод по второму пункту**

# %% [markdown]
# В результате проведеннной предобработки данных:
#
#
# **1. Привели наименование столбцов к нижнему регистру.**
#
#
# **2. Избавились от пропусков в столбцах:**
#    - **name** и **genre:** полностью случайные пропуски - удалили их (так как не влияют на общий массив);
#    - **year_of_release:** случайные пропуски - удалили их (так как их доля всего 1,6 %);
#
#    - **critic_score:**
#         - заменили все пропуски до 1995 года заглушкой -1, так как до этого рейтинга не имели распространение;
#         - с 1995 года по 2016 год заполнили пропуски в зависимости от рейтинга этой же игры на другой платформе;
#         - остальные пропуски заполнили заглушкой -1. Принимаем, что владельцы игры просто отказались от рейтинг.
#    - **user_score:**
#         - пропуска заполнили по аналогии с critic_score;
#         - значения tbd тоже заполнили заглушкой -1. Так как в данном случае мы знаем, что владелец игры отказался от рейтинга.
#    - **rating:** заменили пропуски на TBD. Так как данный рейтинг используется только в Канаде и США.
#
#
# **3. Проверили датафрейм на наличие явных дубликатов:**
#   - отдельно проверили в зависимости от двух столбцов: name и platform. Получили только один дубликат - удалили его.
#   - проверили на неявные дубликаты значений в столбцах genre и platform - отсутствуют.

# %%
data.head(10)
# Out:
#                         name platform  year_of_release         genre  \
# 0                 wii sports      Wii             2006        Sports
# 1          super mario bros.      NES             1985      Platform
# 2             mario kart wii      Wii             2008        Racing
# 3          wii sports resort      Wii             2009        Sports
# 4   pokemon red/pokemon blue       GB             1996  Role-Playing
# 5                     tetris       GB             1989        Puzzle
# 6      new super mario bros.       DS             2006      Platform
# 7                   wii play      Wii             2006          Misc
# 8  new super mario bros. wii      Wii             2009      Platform
# 9                  duck hunt      NES             1984       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     41.36     28.96      3.77         8.45            76         8.0      E
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец, что делаешь промежуточные выводы!  </div>

# %% [markdown]
# ## Исследовательских анализ данных

# %% [markdown]
# ### Распределение выпуска игр в зависимости от года

# %%
ax = data.groupby('year_of_release').count().plot(kind='bar', figsize=(18, 6), grid=True, color='teal', legend=False, stacked = True)

ax.set_title('Количество выпускаемых игр в год', fontsize=16, fontweight='bold')
ax.set_xlabel('Годы', fontsize=12)
ax.set_ylabel('Количество игр', fontsize=12)
ax.grid(axis='x',linestyle='-', linewidth=0.5)  
ax.yaxis.set_major_locator(plt.MaxNLocator(integer=True))

plt.xticks(rotation=45)


plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Очень хорошо, кстати ,что подписываешь графики и оси! </div>

# %% [markdown]
# **Анализируя график может сделать следующие выводы:**
# 1. Пик выпуска игр пришелся на 2008 и 2009 года - рассцвет игровой индустрии.
# 2. Начиная с 2010 года началось падения, в 2012 году индустрия вышла на плато, количество новых игр в год варьируется от 500 до 650 игр.
#
# **Упадок выпускаемых игры можно аргументировать следующим:**
# 1. Рост вовлеченности игроков в онлайн-игры, где апдейтом является как правило не выпуск новой серии, а обновление в рамках действующей версии.
# 2. Увеличение доли мобильных устройств.

# %% [markdown]
# ### Распределение суммарных продаж в зависимости от платформы

# %%
#data['sum_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales'] # определение суммы всех продаж

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Добавление столбца необходимо делать на этапе предобработки данных
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Еще тут можно использовать метод `DataFrame.sum` с аргументом `axis=1`</div>
#
# ```python
#
#         df['total_sum'] = df[['value_1', 'value_2', 'value_3', 'value_4']].sum(axis=1)
#
# ```

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# перенес действие на этап предобработки данных, применил метод DataFrame.sum (п.2.5)
# </div>

# %%
data_platform = data.pivot_table(index = ['platform'], # группировка по платформам и рассчет суммарных продаж за все года
                                 values='sum_sales', 
                                 aggfunc = 'sum').sort_values(by='sum_sales', 
                                                              ascending = False).reset_index()  

data_platform.head(10)
# Out:
#   platform  sum_sales
# 0      PS2    1233.56
# 1     X360     961.24
# 2      PS3     931.33
# 3      Wii     891.18
# 4       DS     802.78
# 5       PS     727.58
# 6      PS4     314.14
# 7      GBA     312.88
# 8      PSP     289.53
# 9      3DS     257.81

# %% [markdown]
# В **топ-10** платформ вошли: *PS2, X360, PS3, Wii, DS, PS, PS4, GBA, PSP, 3DS*.
#
#
# При этом разница продаж между **6 место** *(PS)* и **7 местом** *(PS4)* более, чем в два раза.
#
#
# Исходя из этого, и воизбежания перегрузки графика проанализируем продажи в зависимости от года только по топ-6 платформам.

# %%
data_top_sales = data.pivot_table(index = 'year_of_release', # группировка по платформам и годам с рассчетом суммарных продаж за все года
                                  columns = 'platform',
                                  values = 'sum_sales', 
                                  aggfunc = 'sum').fillna(0)

data_top_sales = data_top_sales[['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']] # Топ-6 платформ

data_top_sales.tail(10)
# Out:
# platform           PS2    X360     PS3     Wii      DS   PS
# year_of_release
# 2007             75.99   95.41   73.19  152.77  146.94  0.0
# 2008             53.90  135.26  118.52  171.32  145.31  0.0
# 2009             26.40  120.29  130.93  206.97  119.54  0.0
# 2010              5.64  170.03  142.17  127.95   85.02  0.0
# 2011              0.45  143.84  156.78   59.65   26.18  0.0
# 2012              0.00   99.74  107.35   21.71   11.01  0.0
# 2013              0.00   88.58  113.25    8.59    1.54  0.0
# 2014              0.00   34.74   47.76    3.75    0.00  0.0
# 2015              0.00   11.96   16.82    1.14    0.00  0.0
# 2016              0.00    1.52    3.60    0.18    0.00  0.0

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Нужно всегда стараться писать более универсальный код, без ручного внесения данных. Если данные дополнятся или изменятся, то список платформ нам придется переписывать, при этом можно допустить ошибки. Лучше сразу формировать список платформ из полученной группировки по продажам и его потом использовать при фильтрации. Ниже написал пример. </div>

# %%
# код ревьюера
data.groupby('platform').agg({'sum_sales': 'sum'}).sort_values(by='sum_sales', ascending=False).head(6).index.to_list()
# Out:
# ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# спасибо, учту!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b>👍  </div>

# %% [markdown]
# **Исходя из подготовленного датафрейма уже видно, что к 2016 году продажи существенно упали.**

# %%
ax = data_top_sales.plot(xticks=data_top_sales.index, figsize=(15,6), linestyle='-')

plt.xticks(rotation = 45) 
plt.grid(True, linestyle='--', linewidth=0.5, color='gray')

ylab = ax.set_ylabel('Продажи, млн копий', fontsize=12)

xlab = ax.set_xlabel('Годы', fontsize=12)

ax.set_ylim(0.5, 220)

plt.title('Распределение суммарных продаж игр на ТОП-6 платформах', fontsize=14, fontweight='bold')

for platform in data_top_sales.columns:
    line_color = ax.get_lines()[data_top_sales.columns.get_loc(platform)].get_c()
    plt.fill_between(data_top_sales.index, data_top_sales[platform], color=line_color, alpha=0.05, label=platform)
 
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Пропуски в сводной таблице лучше не заполнять нулями, чтобы не было лишней горизонтальной линии на отметке 0. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# если убрать ноль получаются обрезанные графики, для того, что бы небыло видно линии на уровне нуля, немного ограничил график по оси y.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍 Графики ведь необязательно должны начинаться от начала оси </div>

# %%
time_top = data.copy()
time_of_life = time_top.pivot_table(index='platform', values='year_of_release', aggfunc={'min', 'max'}).reset_index()
time_of_life['life'] = time_of_life['max'] - time_of_life['min'] + 1


time_top = data.loc[data['platform'].isin(['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS'])]
time_of_life_top = time_top.pivot_table(index='platform', values='year_of_release', aggfunc={'min', 'max'}).reset_index()
time_of_life_top['life'] = time_of_life_top['max'] - time_of_life_top['min'] + 1

print("Средний уровень продолжительности жизни всех платформ:", time_of_life['life'].median())
print("Средний уровень продолжительности жизни ТОП-6 платформ:", time_of_life_top['life'].median())
# Out:
# Средний уровень продолжительности жизни всех платформ: 7.0
# Средний уровень продолжительности жизни ТОП-6 платформ: 11.5

# %% [markdown]
# **Анализируя график можно сделать следующий вывод:**
# 1. Выпуск новых игр на **Топ-6** платформ к 2016 году закончился, либо заканчивается *(это подтверждает гипотезу о том, что пик подошел к концу)*.
#
#
# 2. Средний срок жизни:
#    - всех платформ: **7 лет**
#    - ТОП-6 платформ: **11,5 лет**
#
#
# 3. Для последующего прогноизрования продаж нужно выбрать платформы которые либо подбираются к своему пику, либо только недавно его прошли *(для топ платформ этот срок равен 6 лет, для всех остальных 3 года)*
#
#
# **Исходя из вышесказанного актуальный период принимаем - 4 года, т.е. с 2013 по 2016 год**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Согласен с выбранным актуальным периодом! </div>

# %% [markdown]
# ### Определение наиболее перспктивных платформ

# %%
data_actual = data.query('year_of_release >= 2013').reset_index() 
del data_actual['index']

# %%
data_actual_sum = data_actual.pivot_table(index = ['platform'], 
                                        values='sum_sales', 
                                        aggfunc = 'sum').sort_values(by='sum_sales', 
                                                                     ascending = False).reset_index()
data_actual_sum.head(10)
# Out:
#   platform  sum_sales
# 0      PS4     314.14
# 1      PS3     181.43
# 2     XOne     159.32
# 3      3DS     143.25
# 4     X360     136.80
# 5     WiiU      64.63
# 6       PC      39.43
# 7      PSV      32.99
# 8      Wii      13.66
# 9      PSP       3.50

# %% [markdown]
# Из полученных данных  и на основании предыдущих расчетов мы знаем, что продажи несколько платформ стремятся к нулю:
#    - *PS3, X360, Wii, PSP* - **исключаем сразу**;
#    - *PS4, XOne, 3DS, WiiU, PC, PSV* - **проверим**.

# %%
data_actual_top = data_actual.pivot_table(index = 'year_of_release', # группировка по платформам и годам с рассчетом суммарных продаж за все года
                                  columns = 'platform',
                                  values = 'sum_sales', 
                                  aggfunc = 'sum').fillna(0) 

data_actual_top = data_actual_top[['PS4', 'XOne', '3DS', 'WiiU', 'PC', 'PSV']] 

data_actual_top.tail(10)
# Out:
# platform            PS4   XOne    3DS   WiiU     PC    PSV
# year_of_release
# 2013              25.99  18.96  56.57  21.65  12.38  10.59
# 2014             100.00  54.07  43.76  22.03  13.28  11.90
# 2015             118.90  60.14  27.78  16.35   8.52   6.25
# 2016              69.25  26.15  15.14   4.60   5.25   4.25

# %%
ax = data_actual_top.plot(xticks=data_actual_top.index, figsize=(15,6))

plt.xticks(rotation = 0) 

ylab = ax.set_ylabel('Продажи, млн копий')

xlab = ax.set_xlabel('Годы')

plt.title('Распределение суммарных продаж ТОП-6 платформ', fontsize=14, fontweight='bold')

for platform in data_actual_top.columns:
    line_color = ax.get_lines()[data_actual_top.columns.get_loc(platform)].get_c()
    plt.fill_between(data_actual_top.index, data_actual_top[platform], color=line_color, alpha=0.05, label=platform)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Здесь ведь тоже тогда графики получаются "обрезанными"  </div>

# %% [markdown]
# **Исходя из анализа графика делаем вывод:**
#
#
# 1. Абсолютно по всем платформам графики затухают, вероятно за 2016 год представленны не полные данные.
#
#
# 2. **PS4** и **XOne** вышли только в 2012 году, исходя из срока жизни их прородителей *(PS3, X360)*, можно предположить, что они прослужат до 2023-2024 года и как следствие являются потенциально самыми прибыльными платформами.
#
#
# 3. Отдельно стоит выделить **PC** - это самая долгоиграющая платформа, несмотря на то, что продажи по ней падают, списывать со счетов пока рано.
#
#
# 4. Платформы **3DS, WiiU, PSV** имеют характерный затухающий хараткер, но при этом еще имеют долю рынка - оставляем для дальнейших расчетов.
#
# **ИТОГО**
#
# **Топ прибыльных платформ на ближайший период**:
# 1. *PS4*
# 2. *XOne*
# 3. *3DS*
# 4. *PC*
# 5. *WiiU*

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# WiiU и PSV я бы все-таки не добавлял в список потенциально прибыльных платформ </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# PSV исключил, WiiU оставил, так как показывает очень интересные показатели при подсчете корреляции. Это поможет больше понять японский рынок.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
# Хорошая корреляция не означает потенциал в продажах. По данным последних лет продажи ведь только падают</div>

# %% [markdown]
# ### Построение графика "ящик с усами" по глобальный продажам игр в разбивке платформ

# %%
#top = ['PS4', 'XOne', '3DS', 'WiiU', 'PC', 'PSV']

#data_actual = data_actual[data_actual['platform'].isin(top)]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Далее нам нужно анализировать все данные из актуального периода, без дополнительных фильтраций по платформам. Это позволит нам убедиться в правильности выбора перспективных платформ и не допустить ошибок.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# исключил фильтрация по платформам
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
ax = data_actual.boxplot(column='sum_sales', by='platform', fontsize=10,
                                         boxprops=dict(linestyle='-', linewidth=2),
                                         medianprops=dict(linestyle='-', linewidth=2),
                                         whiskerprops=dict(linestyle='-', linewidth=1),
                                         capprops=dict(linestyle='-', linewidth=1),
                                         notch=True, figsize=(16,8))
ax.set_title('')
ax.title.set_size(10)
ax.set_xlabel('Платформа')
ax.set_ylabel('Продажи, млн')
plt.suptitle('Функция размаха продаж в зависимости от платформ', y=0.93, fontsize=16, fontweight='bold')

plt.show()

# %% [markdown]
# **В графиках наблюдаются явные выбросы - это игры бестселлеры.**
#
# Ограничим значения по оси y, что бы посмотреть ближе.

# %%
ax = data_actual.boxplot(column='sum_sales', by='platform', fontsize=10,
                                         boxprops=dict(linestyle='-', linewidth=2),
                                         medianprops=dict(linestyle='-', linewidth=2),
                                         whiskerprops=dict(linestyle='-', linewidth=1),
                                         capprops=dict(linestyle='-', linewidth=1),
                                         notch=True, figsize=(16,8))
ax.set_title('')
ax.title.set_size(10)
ax.set_ylim(0, 2)
ax.set_xlabel('Платформа')
ax.set_ylabel('Продажи, млн')
plt.suptitle('Функция размаха продаж в зависимости от платформ', y=0.93, fontsize=16, fontweight='bold')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Правильно, что построил две визуализации! </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# исходя из этой диаграммы, мы не можем сказать, что выше выбранные платформы дейсвтительно самые прибыльные на ближайшие годы. Здесь мы видим хорошие показатели у PS3, X360, Wii. Для этого построю еще один график, но ограничусь данными за 2015 год, что бы показать, что продажи затухают.
# </div>

# %%
data_actual_2015 = data_actual.query('year_of_release == 2015').reset_index() 

ax = data_actual_2015.boxplot(column='sum_sales', by='platform', fontsize=10,
                                         boxprops=dict(linestyle='-', linewidth=2),
                                         medianprops=dict(linestyle='-', linewidth=2),
                                         whiskerprops=dict(linestyle='-', linewidth=1),
                                         capprops=dict(linestyle='-', linewidth=1),
                                         notch=True, figsize=(16,8))
ax.set_title('')
ax.title.set_size(10)
ax.set_ylim(0, 2)
ax.set_xlabel('Платформа')
ax.set_ylabel('Продажи, млн')
plt.suptitle('Функция размаха продаж в зависимости от платформ', y=0.93, fontsize=16, fontweight='bold')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# здесь мы видим, что медианные данные по PS3 и X360 значительно снизились, прибавляя к этому сведения из анализа данных из линейного графика выше принимаем, что выбранные топ-5 платформы соотвествуют правде.
# </div>

# %% [markdown]
# **Исходя из анализа графиков можно сделать вывод:**
#
# 1. Большинство игр характеризуются небольшим количеством продаж, так как медианное значение смещенно вниз.
# 2. При этом есть игры с очень большим количеством продаж, на что указывают значительные выбросы.
# 3. Как результат мы имеем, что относительно небольшое количество игр  - дает большой процент от общих продаж.
# 4. Игры на **3DS, PC и PSV** имеют высокий ризк к низким продажам. Учтем этот фактор в дальнейшем - **важно!**

# %% [markdown]
# ### Определим как влияют отызвы критиков и пользователей на продажи игры на PS4

# %%
dataPS4=data_actual.query('platform == "PS4" and user_score > 0')

plt.style.use('seaborn-darkgrid')

plt.figure(figsize=(15, 6))
           
plt.scatter(dataPS4['user_score'], dataPS4['sum_sales'], color='purple', s=100, alpha=0.8, edgecolors='w', linewidth=2)

plt.title('Диаграмма рассеяния', fontsize=14, fontweight='bold')
plt.xlabel('Рейтинг', fontsize=12)
plt.ylabel('Продажи, млн', fontsize=12)

correlation = dataPS4['user_score'].corr(dataPS4['sum_sales'])
print("Корреляция данных:", correlation)

plt.grid(True)
# Out:
# Корреляция данных: -0.031957110204556376

# %% [markdown]
# Корреляция мало того, что очень слабая - она имеет отрицательное значение. Это значит что есть хоть и очень невысокая но обратная зависимость - чем выше рейтинг от игроков, тем ниже продажи.
#
# **В дальнейших расчетах точно не стоит прогнозировать продажи игр на PS4 в зависимости от рейтинга игроков.**

# %%
dataPS4=data_actual.query('platform == "PS4" and critic_score > 0')

plt.style.use('seaborn-darkgrid')

plt.figure(figsize=(15, 6))

plt.scatter(dataPS4['critic_score'], dataPS4['sum_sales'], color='purple', s=100, alpha=0.8, edgecolors='w', linewidth=2)

plt.title('Диаграмма рассеяния', fontsize=14, fontweight='bold')
plt.xlabel('Рейтинг', fontsize=12)
plt.ylabel('Продажи', fontsize=12)

correlation = dataPS4['critic_score'].corr(dataPS4['sum_sales'])
print("Корреляция данных:", correlation)

plt.grid(True)
# Out:
# Корреляция данных: 0.40656790206178095

# %% [markdown]
# Зависимость от оценок критиков уже существенно выше. **Корреляция 0.4 - это умеренная связь.** При этом можно отметить:
# - игры с рейтингом больше 90 исключительные случаи, но вероятность их успеха достаточно высокая;
# - наибольший объем продажи приносят игры с рейтингом от 80 до 90.

# %% [markdown]
# ### Соотнесем выводы с продажами на других платформах

# %%
platforms = ['PS4', 'XOne', '3DS', 'WiiU', 'PC']
results = []

for platform in platforms:
    data_platform = data_actual.query('platform == @platform and user_score > 0')
    correlation_critic = data_platform['critic_score'].corr(data_platform['sum_sales'])
    correlation_user = data_platform['user_score'].corr(data_platform['sum_sales'])
    results.append([platform, correlation_user, correlation_critic])

data_results = pd.DataFrame(results, columns=['platform', 'corrlation_on_user_score', 'dependence_on_critic_score'])
print(data_results)
# Out:
#   platform  corrlation_on_user_score  dependence_on_critic_score
# 0      PS4                 -0.031957                    0.350407
# 1     XOne                 -0.068925                    0.333579
# 2      3DS                  0.241504                    0.277904
# 3     WiiU                  0.419330                    0.348469
# 4       PC                 -0.093842                    0.198016

# %%
data_results.plot(x='platform', y=['corrlation_on_user_score', 'dependence_on_critic_score'], kind='bar', 
                figsize=(18, 6), color=['tan', 'purple'])

plt.title('Корреляции уровня продаж игр на разных платформах в зависимости от пользовательских оценок и оценок критиков', fontsize=16, fontweight='bold')
plt.xlabel('Платформа', fontsize=12)
plt.ylabel('Уровень корреляции', fontsize=12)
plt.xticks(rotation=0)

plt.legend(['Корреляция от оценок пользователей', 'Коррелция от оценок критиков'], loc='upper right')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Очень наглядно получилось! </div>

# %% [markdown]
# **Анализируя график можно сделать следующие заключения:**
#
#
# **1. Выводы которые делали для PS4 полностью распространяются и на XOne, частино на PC и PSV:**
# - по PC можно только отметить что отрицательная корреляция от пользователских оценок еще больше, чем на PS4.
# - коррелиция от оценок критиков по PC и PSV не дотягивает даже до умеренной связи.
#
#
# **2. Для 3DS и WiiU** - уже есть коррелция от оценок пользователей при этом для 3DS она очень слабая, а вот для WiiU - уже умеренная связь и она выше чем любая другая коррелция для всех платформ.
#
# Это может связано с национальной особенностью Японского рынка, т.к. и 3DS и WiiU имеют широкое распространение в стране восходящего солнца.

# %% [markdown]
# ### Посмотрим распределение выпуска игр и продаж в зависимости от жанра

# %% [markdown]
# **План работ:**
# 1. Посмотрим на распределение выпускаемых игр в зависимости от жанра *(построим столбчатую и круговую диаграммы с процентами)*;
# 2. Посмотрим на распределение продаж игр в зависимости от жанра *(построим идентичные диграммы)*;
# 3. Посчитаем средний уровень продаж одной игры в зависимости от жанра.

# %% [markdown]
# #### Распределение выпускаемых игр в завсимости от жанра

# %%
sorted_genre_counts = data_actual['genre'].value_counts().sort_values()

colors = plt.cm.viridis(np.linspace(0, 1, len(sorted_genre_counts))) 

plt.figure(figsize=(12, 8))
sorted_genre_counts.plot(kind='bar', color=colors, figsize=(18, 8))

plt.title('Распределение количества игр по жанрам', fontsize=16, fontweight='bold')
plt.xlabel('Жанр', fontsize=12)
plt.ylabel('Количество игр', fontsize=12)
plt.xticks(rotation=0)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))

colors = plt.cm.viridis(np.linspace(0, 1, len(sorted_genre_counts)))  # использование цветовой карты viridis для плавного перехода цветов

wedges, texts, autotexts = ax.pie(sorted_genre_counts, labels=None, autopct='%1.1f%%', startangle=140, colors=colors, wedgeprops=dict(width=0.4))

for i, autotext in enumerate(autotexts):
    angle = (wedges[i].theta2 + wedges[i].theta1) / 2
    r = 1.1*wedges[i].r
    x = r*np.cos(np.radians(angle))
    y = r*np.sin(np.radians(angle))
    autotext.set_position((x, y))
    autotext.set_fontsize(12)
    autotext.set_fontweight('bold')

ax.legend(sorted_genre_counts.index, loc="center right", bbox_to_anchor=(1.5, 0.5), fontsize=15)

ax.set_title('Распределение количества игр по жанрам', fontsize=16, fontweight='bold')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
#
# Если значений, отображаемых на графике, более 6, то использовать кольцевую(круговую) диаграмму не рекомендуется. Можно выделить, например, топ-5 жанров, а остальные объединить в отдельную категорию.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# на этой диаграмме стралася, что бы все было видно и без группировки. Дальше (п.4.1) учел это замечание.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> 👍  </div>

# %% [markdown]
# **Вывод:**
# 1. Наибольшее количество выпускаемых игр приходится на жанр **Action** *(занимает треть рынка)*, наименьшее количество - **Puzzle**.
# 2. Два жанра **Action** и **Role-Playing** занимают половину рынка.

# %% [markdown]
# #### Распределение суммарных продаж игр в зависимости от жанра

# %%
data_actual_genre = data_actual.pivot_table(index = 'genre', values = 'sum_sales', 
                                  aggfunc = 'sum').sort_values(by='sum_sales')


colors = plt.cm.coolwarm(np.linspace(0, 1, len(data_actual_genre['sum_sales'])))


plt.figure(figsize=(12, 8))
ax = data_actual_genre['sum_sales'].plot(kind='bar', color=colors, figsize=(18, 8), stacked = 'True')


plt.title('Суммарные продажи игр по жанрам', fontsize=16, fontweight='bold')
plt.xlabel('Жанр', fontsize=12)
plt.ylabel('Суммарные продажи', fontsize=12)
plt.xticks(rotation=0)


plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
colors = plt.cm.coolwarm(np.linspace(0, 1, len(data_actual_genre['sum_sales'])))

wedges, texts, autotexts = ax.pie(data_actual_genre['sum_sales'], labels=None, autopct='%1.1f%%', startangle=140, colors=colors, wedgeprops=dict(width=0.4))

for i, autotext in enumerate(autotexts):
    angle = (wedges[i].theta2 + wedges[i].theta1) / 2
    r = 1.1*wedges[i].r
    x = r*np.cos(np.radians(angle))
    y = r*np.sin(np.radians(angle))
    autotext.set_position((x, y))
    autotext.set_fontsize(12)
    autotext.set_fontweight('bold')

ax.legend(data_actual_genre.index, loc="center right", bbox_to_anchor=(1.5, 0.5), fontsize=15)
    
ax.set_title('Суммарные продажи игр по жанрам', fontsize=16, fontweight='bold')

plt.show()

# %% [markdown]
# **Вывод:**
# 1. Наибольшую долю рынка продаж игр занимают жанр **Action**, самую низкую в жанре **Puzzle**.
# 2. На долю трех самых популярных жанров: **Action, Shooter, Role-Plaqying** - приходится **63 %** процента всех продаж. Это существенная доля рынка.
# 3. На долю шести самых популярных жанров *(половина)* уже приходится **85 %** всех продаж. Это подавляющая доля рынка.

# %% [markdown]
# #### Расчет средного и медианного количества продаж одной игры в зависимости от жанра

# %%
colors = plt.cm.magma(np.linspace(0, 1, len(data_actual_genre['sum_sales']))) 

average_sales_by_genre = data_actual.groupby('genre')['sum_sales'].sum() / data_actual['genre'].value_counts()

average_sales_by_genre = average_sales_by_genre.sort_values()

plt.figure(figsize=(12, 8))
average_sales_by_genre.plot(kind='bar', color=colors, figsize=(18, 8))

plt.title('Среднее количество продаж одной игры по жанрам', fontsize=16, fontweight='bold')
plt.xlabel('Жанр', fontsize=12)
plt.ylabel('Среднее количество продаж', fontsize=12)
plt.xticks(rotation=0)

plt.show()

# %%
median_sales_by_genre = data_actual.groupby('genre')['sum_sales'].median()

median_sales_by_genre = median_sales_by_genre.sort_values()

plt.figure(figsize=(12, 8))
colors = plt.cm.magma(np.linspace(0, 1, len(data_actual_genre['sum_sales'])))
median_sales_by_genre.plot(kind='bar', color=colors, figsize=(18, 8))

plt.title('Медианное количество продаж одной игры по жанрам', fontsize=16, fontweight='bold')
plt.xlabel('Жанр', fontsize=12)
plt.ylabel('Медианное количество продаж', fontsize=12)
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# **Вывод. Здесь уже результаты интереснее:**
# 1. Лидером и по среднему, и по медианному уровню продаж стал жанр **Shooter**, так же в лидеры вышли жанры **Platform** и **Sports**
# 2. Показатели в жанре **Action** *(лидер и по выпуску новых игр, и по общим продажам)* здесь заняли невысокие позиции.

# %% [markdown]
# **ИТОГО: принимаем, что самые перспективные и стабильные жанры это Shooter, Sports и Platform.**
#
# Проверим данную гипотезу на диаграмме размаха:

# %%
ax = data_actual.boxplot(column='sum_sales', by='genre', fontsize=10,
                                         boxprops=dict(linestyle='-', linewidth=2),
                                         medianprops=dict(linestyle='-', linewidth=2),
                                         whiskerprops=dict(linestyle='-', linewidth=1),
                                         capprops=dict(linestyle='-', linewidth=1),
                                         notch=True, figsize=(16,8))
ax.set_title('')
ax.title.set_size(10)
ax.set_ylim(0, 10)
ax.set_xlabel('Платформа')
ax.set_ylabel('Продажи, млн')
plt.suptitle('Функция размаха продаж в зависимости от платформ', y=0.93, fontsize=16, fontweight='bold')

plt.show()

# %% [markdown]
# **Гипотеза подтвердилась:** платформы Shooter, Platform и Sports имеют относительно небольшое количество выбросов, при этом самые высокие средние и медианные значения.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Отлично! Молодец, что взял для вывода именно медианные продажи, это наиболее объективный показатель прибыльности, так как они не подвержены влиянию выбросов (которых в игровой индустрии достаточно много за счет продаж хитовых и популярных игр).
# </div>

# %% [markdown]
# ### **Вывод по третьему пункту**

# %% [markdown]
# **В результате проведенного исследовательского анализа данных:**
# 1. **Распределили выпуск игр в зависимоти от года:**
#    - пик выпуска игр пришелся на 2008 и 2009 года - рассцвет игровой индустрии;
#    - начиная с 2010 года началось падение, в 2012 году индустрия вышла на плато, количество новых игр в год варьируется от 500 до 650 игр;
#    - упадок выпускаемых игры можно аргументировать следующим:
#      - рост вовлеченности игроков в онлайн-игры, где апдейтом является как правило не выпуск новой серии, а обновление в рамках действующей версии;
#      - увеличение доли мобильных устройств.
#
#
# 2. **Распределили суммарные продажи в зависимости от платформы:**
#    - в **топ-6** платформ по продажам за все время вошли: *PS2, X360, PS3, Wii, DS, PS*. При этом к 2016 году уровень продаж игр на эти платформы либо равен нулю, либо стремится к нему;
#
#
# 3. **Определили наиболее перспективные платформы:**
#    - в топ перспективных платформ вошли: *PS4, XOne, 3DS, WiiU, PC, PSV*
#    - определили акутальный период для анализа для прогнозирования - **4 года**
#
#
# 4. **Определили зависимость продаж игры в зависимости от пользовательских оценок и оценок критиков:**
#    - для PS4, XOne, PC
#       - корреляция с пользовательскими оценками мало того, что очень слабая - она имеет отрицательное значение. Это значит что есть хоть и очень невысокая но обратная зависимость - чем выше рейтинг от игроков, тем ниже продажи.
#    - для 3DS и WiiU
#       - уже есть коррелция от оценок пользователей при этом для 3DS она очень слабая, а вот для WiiU - уже умеренная связь и она выше чем любая другая коррелция для всех платформ.
#
#
# 5. **Определили зависиомсть продаж игр в зависимости от платформы:**
#    - самые перспективные и стабильные жанры это Shooter, Sports и Platform.

# %% [markdown]
# ## Составление портрета пользователя в зависимости от региона

# %% [markdown]
# В датафрейме представленные данные по трем регионам: **eu_sales** *(Европа)*, **na_sales** *(Северная Америка)*, **jp_sales** *(Япония)*

# %% [markdown]
# ### Определение топ-5 платформ по продажам для каждого региона

# %%
data_actual_region = data_actual.groupby('platform')[['na_sales', 'eu_sales', 'jp_sales']].sum()

data_actual_region['na_share'] = data_actual_region['na_sales'] / data_actual_region['na_sales'].sum()*100
data_actual_region['eu_share'] = data_actual_region['eu_sales'] / data_actual_region['eu_sales'].sum()*100
data_actual_region['jp_share'] = data_actual_region['jp_sales'] / data_actual_region['jp_sales'].sum()*100

data_actual_region = data_actual_region.round(2)

data_actual_region_styled = data_actual_region.style.format({
    'na_share': '{:.2f}%',
    'eu_share': '{:.2f}%',
    'jp_share': '{:.2f}%'
})

data_actual_region_styled
# Out:
# <style  type="text/css" >
# </style><table id="T_0af2b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >na_sales</th>        <th class="col_heading level0 col1" >eu_sales</th>        <th class="col_heading level0 col2" >jp_sales</th>        <th class="col_heading level0 col3" >na_share</th>        <th class="col_heading level0 col4" >eu_share</th>        <th class="col_heading level0 col5" >jp_share</th>    </tr>    <tr>        <th class="index_name level0" >platform</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0af2b_level0_row0" class="row_heading level0 row0" >3DS</th>
#                         <td id="T_0af2b_row0_col0" class="data row0 col0" >38.200000</td>
# ...

# %%
top5_platforms_na = data_actual_region['na_sales'].nlargest(5)
top5_platforms_eu = data_actual_region['eu_sales'].nlargest(5)
top5_platforms_jp = data_actual_region['jp_sales'].nlargest(5)

other_na_sales = data_actual_region['na_sales'].sum() - top5_platforms_na.sum()
other_eu_sales = data_actual_region['eu_sales'].sum() - top5_platforms_eu.sum()
other_jp_sales = data_actual_region['jp_sales'].sum() - top5_platforms_jp.sum()

platforms_na = top5_platforms_na.index
platforms_eu = top5_platforms_eu.index
platforms_jp = top5_platforms_jp.index

fig, axs = plt.subplots(1, 3, figsize=(20, 6))

region_titles = ['Доли продаж в Северной Америке', 'Доли продаж в Европе', 'Доли продаж в Японии']

for i, (top5, other_sales, platforms, region_title) in enumerate(zip([top5_platforms_na, top5_platforms_eu, top5_platforms_jp], [other_na_sales, other_eu_sales, other_jp_sales], [platforms_na, platforms_eu, platforms_jp], region_titles)):
    labels = platforms.tolist() + ['Other']
    sizes = top5.tolist() + [other_sales]
    colors = plt.cm.tab20c.colors[:len(labels)]  # Используем цвета из tab20c colormap
    wedges, texts, autotexts = axs[i].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors, wedgeprops=dict(width=0.25))
    axs[i].set_title(region_title, fontsize=16)
    for autotext in autotexts:
        autotext.set_fontsize(14)


plt.suptitle('Распределение продаж игр для трех регионов в зависимости от платформы', y=1.05, fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Супер! </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# с учетом замечания выше, пришлось поправить и этот график, учитывая все платформы, а не только топ-6.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично!👍  </div>

# %%
top_platforms_na = data_actual_region['na_share'].nlargest(5)
top_platforms_eu = data_actual_region['eu_share'].nlargest(5)
top_platforms_jp = data_actual_region['jp_share'].nlargest(5)

top_platforms = pd.DataFrame({
    'Топ платформ в NA': top_platforms_na.index,
    'Доля продаж в NA': top_platforms_na.values.round(2),
    'Топ платформ в EU': top_platforms_eu.index,
    'Доля продаж в EU': top_platforms_eu.values.round(2),
    'Топ платформ в JP': top_platforms_jp.index,
    'Доля продаж в JP': top_platforms_jp.values.round(2)
})

top_platforms
# Out:
#   Топ платформ в NA  Доля продаж в NA Топ платформ в EU  Доля продаж в EU  \
# 0               PS4             24.84               PS4             35.97
# 1              XOne             21.27               PS3             17.29
# 2              X360             18.66              XOne             13.15
# 3               PS3             14.51              X360             10.84
# 4               3DS              8.73               3DS              7.89
#
#   Топ платформ в JP  Доля продаж в JP
# 0               3DS             48.17
# 1               PS3             16.59
# 2               PSV             13.21
# 3               PS4             11.34
# 4              WiiU              7.73

# %% [markdown]
# **Из анализа графиков и полученных даннных можно сделать следующее заключение:**
#
# 1. Картина по топ-5 платформ для Северной Америке и Европы похожа, только в Европе куда более сильную популрность приставки Sony **(и новая, и предыдущая версии)**
#
# 2. Для Японии картина координально другая:
#    - здесь существенную долю продаж имеет портативная приставка **3DS**;
#    - **PC** не используется совсем;
#    - Американская платформа **XOne** имеет незначительную долю рынка.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# поправил вывод.
# </div>

# %% [markdown]
# ### Определение топ-5 жанров по продажам для каждого региона

# %%
data_actual_genre = data_actual.groupby('genre')[['na_sales', 'eu_sales', 'jp_sales']].sum()

data_actual_genre['na_share'] = data_actual_genre['na_sales'] / data_actual_genre['na_sales'].sum()*100
data_actual_genre['eu_share'] = data_actual_genre['eu_sales'] / data_actual_genre['eu_sales'].sum()*100
data_actual_genre['jp_share'] = data_actual_genre['jp_sales'] / data_actual_genre['jp_sales'].sum()*100

data_actual_genre = data_actual_genre.round(2)

data_actual_genre_styled = data_actual_genre.style.format({
    'na_share': '{:.2f}%',
    'eu_share': '{:.2f}%',
    'jp_share': '{:.2f}%'
})

data_actual_genre_styled
# Out:
# <style  type="text/css" >
# </style><table id="T_45da4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >na_sales</th>        <th class="col_heading level0 col1" >eu_sales</th>        <th class="col_heading level0 col2" >jp_sales</th>        <th class="col_heading level0 col3" >na_share</th>        <th class="col_heading level0 col4" >eu_share</th>        <th class="col_heading level0 col5" >jp_share</th>    </tr>    <tr>        <th class="index_name level0" >genre</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45da4_level0_row0" class="row_heading level0 row0" >Action</th>
#                         <td id="T_45da4_row0_col0" class="data row0 col0" >126.050000</td>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = data_actual_genre.index
sizes_na = data_actual_genre['na_sales']
sizes_eu = data_actual_genre['eu_sales']
sizes_jp = data_actual_genre['jp_sales']
colors = ['teal', 'indianred', 'cornflowerblue']
bar_width = 0.3
x = np.arange(len(labels))

fig, ax = plt.subplots(figsize=(16, 6))
ax.bar(x - 0.3, sizes_na, width=bar_width, color=colors[0], label='Северная Америка')
ax.bar(x, sizes_eu, width=bar_width, color=colors[1], label='Европа')
ax.bar(x + 0.3, sizes_jp, width=bar_width, color=colors[2], label='Япония')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_title('Уровень продаж в различных регионах', fontsize=16, fontweight='bold')
ax.legend()

plt.show()

# %%
top_platforms_na = data_actual_genre['na_share'].nlargest(5)
top_platforms_eu = data_actual_genre['eu_share'].nlargest(5)
top_platforms_jp = data_actual_genre['jp_share'].nlargest(5)

top_platforms = pd.DataFrame({
    'Топ жанров NA': top_platforms_na.index,
    'Доля продаж в NA': top_platforms_na.values.round(2),
    'Топ жанров в EU': top_platforms_eu.index,
    'Доля продаж в EU': top_platforms_eu.values.round(2),
    'Топ жанров в JP': top_platforms_jp.index,
    'Доля продаж в JP': top_platforms_jp.values.round(2)
})

top_platforms
# Out:
#   Топ жанров NA  Доля продаж в NA Топ жанров в EU  Доля продаж в EU  \
# 0        Action             28.80          Action             30.12
# 1       Shooter             25.07         Shooter             22.40
# 2        Sports             14.91          Sports             15.43
# 3  Role-Playing             10.60    Role-Playing              9.43
# 4          Misc              6.28          Racing              5.15
#
#   Топ жанров в JP  Доля продаж в JP
# 0    Role-Playing             36.26
# 1          Action             28.76
# 2            Misc              6.54
# 3        Fighting              5.43
# 4         Shooter              4.70

# %% [markdown]
# **Из анализа графиков и полученных даннных можно сделать следующее заключение:**
#
# 1. Для Северной Америки и Европы более 50 % процентов всех продаж приходится на жанры Shooter и Action.
# 2. Для Японии существнную долю рынка занимаем жанра Role-Playing.
# 3. В целом рынок для Северной Америки и Европы схожий, для Японии снова наблюдаются существенные отличия.

# %% [markdown]
# ### Определение влияние рейтинга ESRB на продажи в Северной Америке

# %% [markdown]
# **Рейтинг ESRB** - является возрастным рейтингом.

# %%
data_ESRB_sum = data_actual.groupby('rating')['na_sales'].sum()
data_ESRB_count = data_actual.groupby('rating')['na_sales'].count()
data_ESRB_median = data_actual.groupby('rating')['na_sales'].median()
data_ESRB_mean = data_actual.groupby('rating')['na_sales'].mean()

# %%
data_ESRB = pd.DataFrame({
    'sum_sales': data_ESRB_sum,
    'game_count': data_ESRB_count,
    'median_sales_per_game': data_ESRB_median,
    'mean_sales_per_game': data_ESRB_mean
})

data_ESRB_filtered = data_ESRB[data_ESRB.index != 'TBD']

styled_table = data_ESRB_filtered.style.format({
    'sum_sales': '{:.2f}',
    'median_sales_per_game': '{:.2f}',
    'mean_sales_per_game': '{:.2f}'
}).set_table_styles([{
    'selector': 'th',
    'props': [('background-color', 'lightgrey'), ('color', 'black'), ('font-size', '14px')]
}])

styled_table
# Out:
# <style  type="text/css" >
#     #T_d681c_ th {
#           background-color: lightgrey;
#           color: black;
#           font-size: 14px;
#     }</style><table id="T_d681c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sum_sales</th>        <th class="col_heading level0 col1" >game_count</th>        <th class="col_heading level0 col2" >median_sales_per_game</th>        <th class="col_heading level0 col3" >mean_sales_per_game</th>    </tr>    <tr>        <th class="index_name level0" >rating</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d681c_level0_row0" class="row_heading level0 row0" >E</th>
#                         <td id="T_d681c_row0_col0" class="data row0 col0" >79.05</td>
# ...

# %% [markdown]
# **Приведенные рейтинги:**
# 1. **E** -  подходит для всех возрастных категорий
# 2. **E 10+** - подходит для лиц старше 10 лет
# 3. **M** - подходит для лиц старше 17 лет
# 4. **T** - подходит для лиц старше 13 лет

# %%
data_ESRB_filtered = data_ESRB[data_ESRB.index != 'TBD']

plt.figure(figsize=(10, 7))
bars = plt.bar(data_ESRB_filtered.index, data_ESRB_filtered['median_sales_per_game'], color='darkslateblue')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', fontsize=10)

plt.title('Медианная продажа игр в зависимости от рейтинга ESRB', fontsize=16)
plt.xlabel('Рейтинг ESRB')
plt.ylabel('Медианная продажа')
plt.xticks(rotation=0)
plt.show()

# %%
#data_actual_no_tbd = data_actual[data_actual['rating'] != 'TBD']

ax = data_actual.boxplot(column='na_sales', by='rating', fontsize=10,
                                boxprops=dict(linestyle='-', linewidth=2),
                                medianprops=dict(linestyle='-', linewidth=2),
                                whiskerprops=dict(linestyle='-', linewidth=1),
                                capprops=dict(linestyle='-', linewidth=1),
                                notch=True, figsize=(16, 8))
ax.set_title('')
ax.title.set_fontsize(10)
ax.set_ylim(0, 3)
ax.set_xlabel('Рейтинг ESRB')
ax.set_ylabel('Продажи, млн')
plt.suptitle('Функция размаха продаж в зависимости от платформ', y=0.93, fontsize=16, fontweight='bold')

plt.show()

# %% [markdown]
# **Исходя из полученных данных и анализа графиков можно сделать следующий вывод:**
# 1. Игры с рейтингов **E 10+** и **M** - имеются самые стабильные продажи, при этом для рейтинга **M**  иногда выходят игры с очень высокими продажами.
#
# 2. Игры с рейтингов **E** и **T** - менее стабильны, при этом для рейтинг **E** иногда выходят игры с очень высокими продажами.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# А если заполнить пропуски в рейтингах каким-нибудь единым значением, означающим отсутствие рейтинга, то можно будет увидеть интересную особенность)</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# добавил информацию об играх без рейтинга, можно сделать следующий вывод:
# - игры без рейтинга имееют очень низкие средние продажи
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
# А если посмотреть продажи в разрезе регионов?</div>

# %% [markdown]
# ### **Выводы по четвертому пункту**
# 1. **Определили топ-5 платформ для каждого региона:**
#    - картина по топ-5 платформ для Северной Америке и Европы похожа, только в Европе куда более сильную популрность приставки Sony **(и новая, и предыдущая версии)**
#    - для Японии картина координально другая:
#       - здесь существенную долю продаж имеет портативная приставка **3DS**;
#       - **PC** не используется совсем;
#       - Американская платформа **XOne** имеет незначительную долю рынка.
#
#
# 2. **Определили топ-5 жанров для каждого региона:**
#    - для Северной Америки и Европы более 50 % процентов всех продаж приходится на жанры Shooter и Action.
#    - для Японии существнную долю рынка занимаем жанра Role-Playing.
#    - в целом рынок для Северной Америки и Европы схожий, для Японии снова наблюдаются существенные отличия.
#
#
# 3. **Определили зависимость продаж от рейтинга ESRB для Северной Америки**:
#    - игры с рейтингов **E 10+** и **M** - имеются самые стабильные продажи, при этом для рейтинга **M**  иногда выходят игры с очень высокими продажами.
#    - игры с рейтингов **E** и **T** - менее стабильны, при этом для рейтинг **E** иногда выходят игры с очень высокими продажами.

# %% [markdown]
# ### **Портрет пользователя**

# %% [markdown]
# | Регион          | Платформа          | Жанр                | Возрастной цензор   |
# |-----------------|--------------------|---------------------|---------------------|
# | Северная Америка | PS4, XOne          | Shooter, Action     | 10+, 17+            |
# | Европа          | PS4, XOne          | Shooter, Action     | -          |
# | Япония          | 3DS                | Role-Playing, Action| -                   |

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# **H0** (нулевая гипотеза) - средние пользовательские рейтинги платформы XOne и PC **равны**
#
# **H1** (альтернативная гипотеза) - средние пользователские рейтинги платформы XOne и PC **не равны**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Здорово, что формулируешь гипотезы перед проверкой </div>

# %%
data_actual_XOne_PC = data_actual.loc[(data_actual['platform'].isin(['XOne', 'PC'])) & (data_actual['user_score'] >= 0), ['platform', 'user_score']]
ax = data_actual_XOne_PC.boxplot(column='user_score', by='platform', fontsize=12,
                                 boxprops=dict(linestyle='-', linewidth=2),
                                 medianprops=dict(linestyle='-', linewidth=2),
                                 whiskerprops=dict(linestyle='-', linewidth=2),
                                 capprops=dict(linestyle='-', linewidth=2),
                                 notch=True, figsize=(16, 7))

ax.set_title('') 
ax.set_xlabel('Платформа')
ax.set_ylabel('Оценка пользователей')
plt.suptitle('Функция размаха по оценкам пользователей на платформах XOne и PC', y=0.93, fontsize=16, fontweight='bold')
plt.show()

# %%
data_actual_XOne = data_actual_XOne_PC[(data_actual_XOne_PC['platform'] == 'XOne') & (data_actual_XOne_PC['user_score'] >= 0)]['user_score']

data_actual_PC = data_actual_XOne_PC[(data_actual_XOne_PC['platform'] == 'PC') & (data_actual_XOne_PC['user_score'] >= 0)]['user_score']

# %%
data_actual_XOne
# Out:
# 22      7.9
# 24      5.4
# 31      6.4
# 39      6.2
# 55      4.1
#        ...
# 2179    6.8
# 2194    6.0
# 2204    8.2
# 2208    6.6
# 2215    6.7
# Name: user_score, Length: 182, dtype: float64

# %% [markdown]
# Проверим гипотезу **используя двухвыборочный t-тест для независимых выборок.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# А не забыл ли ты кое-что отфильтровать? )</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# да, забыл исключить заглушку (-1), хотя это было видно и на графике. Исправил.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
alpha = 0.05

results = st.ttest_ind(data_actual_XOne, data_actual_PC, alternative = 'two-sided') 

print('p-значение: ', results.pvalue) 

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.14012658403611647
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# **H0** (нулевая гипотеза) - **отвергнуть не удалось.**
#
# **Вероятность, что средние пользовательские рейтинги платформ XOne и PC не имеют статистически значимых отличий 14%**
#
# **Для рассчетов использовался:**
#  - двухвыборочный t-тест для независимых выборок *(выборки независимы друг от друга, при этом мы имеем два массива данных)*
#  - параметр alternative = two-sided *(у нас небыло задачи определить больше, либо меньше пользовательские рейтинги)*
#  - alpha = 0.05 *(5% вероятность ошибочно отвергнуть нулевую гипотезу, когда она верна - общепринятая практика)*

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Мы не можем сказать, что средние пользовательские рейтинги платформ Xbox One и PC равны (можешь убедиться, что они разные). Мы лишь говорим ,что не можем отвергнуть нулевую гипотезу и что с большой долей вероятности средние пользовательские рейтинги платформ XOne и PC не имеют статистически значимых отличий.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# поправил
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action и Sports разные.

# %% [markdown]
# **H0** (нулевая гипотеза) - средние пользовательские рейтинги жанров Action и Sports**равны**
#
# **H1** (альтернативная гипотеза) - средние пользователские рейтинги жанров Action и Sports **не равны**

# %%
data_actual_action_sports = data_actual.loc[(data_actual['genre'].isin(['Action', 'Sports'])) & (data_actual['user_score'] >= 0)]

plt.figure(figsize=(16, 7))
ax = data_actual_action_sports.boxplot(column='user_score', by='genre', fontsize=12,
                                       boxprops=dict(linestyle='-', linewidth=2),
                                       medianprops=dict(linestyle='-', linewidth=2),
                                       whiskerprops=dict(linestyle='-', linewidth=2),
                                       capprops=dict(linestyle='-', linewidth=2),
                                       notch=True, figsize=(16, 7))
ax.set_title('')
ax.title.set_fontsize(12)
ax.set_xlabel('Жанр')
ax.set_ylabel('Пользовательский рейтинг')
plt.suptitle('Функция размаха пользовательского рейтинга для жанров Action и Sports', y=0.93, fontsize=16, fontweight='bold')

plt.show()

# %%
data_actual_action = data_actual[data_actual['genre'] == 'Action']
data_actual_action = data_actual_action[data_actual_action['user_score'] >= 0]['user_score']

data_actual_sports = data_actual[data_actual['genre'] == 'Sports']
data_actual_sports = data_actual_sports[data_actual_sports['user_score'] >= 0]['user_score']

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Здесь аналогично, необходимо исключить значения-заглушки, которыми были заполнены пропуски.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# поправил
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
alpha = 0.05

results = st.ttest_ind(data_actual_action, data_actual_sports, alternative = 'two-sided')

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  1.0517832389140023e-27
# Отвергаем нулевую гипотезу

# %% [markdown]
# **H0** (нулевая гипотеза) - **отвергнута.**
#
# Вероятность того, что пользовательские рейтинги жанров Action и Sports равны очень низкая - а то, что они разные очень высокая.
#
# **Для рассчетов использовались аналогичные параметры**

# %% [markdown]
# ### **Выводы по пятому пункту**

# %% [markdown]
# 1. Подтвердилась гипотеза о том, что средние пользовательские рейтинги у платформ XOne и PC одинаковые.
# 2. Через опровержение гипотезы о том, что средние пользовательские рейтинги у жанров Action и Sports одинаковые выяснили, что они разные.

# %% [markdown]
# ## **Общий вывод:**
#
# **1. Познакомились с данными:**
#    - датафрейм представляет из себя массив данных, включающий 11 столбцов и 16715 строк.
#    - присутствовали незначительные пропуски в столбцах: **name, year_of_release, genre**.
#    - присутствовали существенные пропуски в столбцах: **critic_score, user_score, reating**.
#
#
# **2. Провели предобработку данных:**
#
#    - привели наименование столбцов к нижнему регистру.**
#    - избавились от пропусков в столбцах:**
#      - **name** и **genre:** полностью случайные пропуски - удалили их (так как не влияют на общий массив);
#      - **year_of_release:** случайные пропуски - удалили их (так как их доля всего 1,6 %);
#      - **critic_score:**
#         - заменили все пропуски до 1995 года заглушкой -1, так как до этого рейтинга не имели распространение;
#         - с 1995 года по 2016 год заполнили пропуски в зависимости от рейтинга этой же игры на другой платформе;
#         - остальные пропуски заполнили заглушкой -1. Принимаем, что владельцы игры просто отказались от рейтинг.
#      - **user_score:**
#         - пропуска заполнили по аналогии с critic_score;
#         - значения tbd тоже заполнили заглушкой -1. Так как в данном случае мы знаем, что владелец игры отказался от рейтинга.
#      - **rating:** заменили пропуски на TBD. Так как данный рейтинг используется только в Канаде и США.
#   - проверили датафрейм на наличие явных и неявных дубликатов
#
#
#
#
# **3. Провели исследовательский анализ данных:**
# - распределили выпуск игр в зависимоти от года:
#    - пик выпуска игр пришелся на 2008 и 2009 года - рассцвет игровой индустрии;
#    - начиная с 2010 года началось падение, в 2012 году индустрия вышла на плато, количество новых игр в год варьируется от 500 до 650 игр;
#    - упадок выпускаемых игры можно аргументировать следующим:
#      - рост вовлеченности игроков в онлайн-игры, где апдейтом является как правило не выпуск новой серии, а обновление в рамках действующей версии;
#      - увеличение доли мобильных устройств.
#
# - распределили суммарные продажи в зависимости от платформы:
#    - в **топ-6** платформ по продажам за все время вошли: *PS2, X360, PS3, Wii, DS, PS*. При этом к 2016 году уровень продаж игр на эти платформы либо равен нулю, либо стремится к нему;
#
# - определили наиболее перспективные платформы:
#    - в топ перспективных платформ вошли: *PS4, XOne, 3DS, WiiU, PC, PSV*
#    - определили акутальный период для анализа для прогнозирования - **4 года**
#
# - определили зависимость продаж игры в зависимости от пользовательских оценок и оценок критиков:
#    - для PS4, XOne, PC
#       - корреляция с пользовательскими оценками мало того, что очень слабая - она имеет отрицательное значение. Это значит что есть хоть и очень невысокая но обратная зависимость - чем выше рейтинг от игроков, тем ниже продажи.
#    - для 3DS и WiiU
#       - уже есть коррелция от оценок пользователей при этом для 3DS она очень слабая, а вот для WiiU - уже умеренная связь и она выше чем любая другая коррелция для всех платформ.
#
# - определили зависиомсть продаж игр в зависимости от платформы:
#    - самые перспективные и стабильные жанры это Shooter, Sports и Platform.
#
#
#
# **4. Составили портрет пользователей в заисимости от региона:**
# - определили топ-5 платформ для каждого региона:
#    - картина по топ-5 платформ для Северной Америке и Европы похожа, только в Европе куда более сильную популрность приставки Sony **(и новая, и предыдущая версии)**
#    - для Японии картина координально другая:
#       - здесь существенную долю продаж имеет портативная приставка **3DS**;
#       - **PC** не используется совсем;
#       - Американская платформа **XOne** имеет незначительную долю рынка.
#
# - определили топ-5 жанров для каждого региона:
#    - для Северной Америки и Европы более 50 % процентов всех продаж приходится на жанры Shooter и Action.
#    - для Японии существнную долю рынка занимаем жанра Role-Playing.
#    - в целом рынок для Северной Америки и Европы схожий, для Японии снова наблюдаются существенные отличия.
#
# - определили зависимость продаж от рейтинга ESRB для Северной Америки:
#    - игры с рейтингов **E 10+** и **M** - имеются самые стабильные продажи, при этом для рейтинга **M**  иногда выходят игры с очень высокими продажами.
#    - игры с рейтингов **E** и **T** - менее стабильны, при этом для рейтинг **E** иногда выходят игры с очень высокими продажами.
#
# - составили портрет пользователя для каждого региона:
# | Регион          | Платформа          | Жанр                | Возрастной цензор   |
# |-----------------|--------------------|---------------------|---------------------|
# | Северная Америка | PS4, XOne          | Shooter, Action     | 10+, 17+            |
# | Европа          | PS4, XOne          | Shooter, Action     | -          |
# | Япония          | 3DS                | Role-Playing, Action| -                   |
#
# **5. Проверили основные гипотезы:**
# - **подтвердилась** гипотеза о том, что **средние пользовательские рейтинги у платформ XOne и PC одинаковые**.
# - через опровержение гипотезы о том, **что средние пользовательские рейтинги у жанров Action и Sports одинаковые выяснили, что они разные**.

# %% [markdown]
# ## **Рекомендации бизнесу**:

# %% [markdown]
# 1. Для рынка **Северной Америки**:
# - самыми перспективными платформами ближайшего периода будут являться PS4 и XOne
#   - при прогнозировании продаж для этих платформ можно учитывать рейтинги критиков, на рейтинги пользователей опираться нельзя
# - самыми популярнми жанрами будут являться Shooter и Action
# - стоит учитывать игры с возрастным цензром: 10+ и 17+
#
# 2. Для рынка **Европы**:
# - почти половина рынка занимает платформа PS4, стоит на неё ориентировать в первую очередь:
#    - при прогнозировании продаж для этой платформы можно учитывать рейтинги критиков, на рейтинги пользователей опираться нельзя
# - самыми популярнми жанрами будут так являться Shooter и Action
#
# 3. Для рынка **Японии**:
# - самая популрная платформа для этого рынка - 3DS, на неё определенно стоит сделать акцент:
#    - при прогнозировании продаж для этой платформы можно учитывать рейтинги критиков, с меньше долей вероятностью рейтинги пользователей
# - вторая по популярности платформа PSV - но по ней нужно предостеречь, есть высокая вероятность, что игры проваляться в продажах
# - самый популярный жанр: Role-Playing и Action.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Отличный резюмирующий вывод! Молодец, что не забыл дать рекомендации на 2017 год.
#
# В целом проект получился очень хорошим. Ты уверенно обращаешься с данными, отлично их анализируешь и строишь прекрасные визуализации! Нужно только переопределить актуальный период, подправить несколько замечаний и будет супер!
#
# **Хочу обратить твое внимание на то, что после исправления замечаний в некоторых пунктах исследования могут измениться результаты, поэтому нужно будет подкорректировать выводы.**</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# спасибо за замечания, все поправил. Существенно в выводах изменился только один момент, в выбронный период еще имели свой вес приставки Xbox и PS3, но с учетом построенных графиков, мы знаем, их показатели сильно затухают, и жизнь заканчивается. Поэтому влияния на рекомендации бизнесса это не оказало.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> 👍  </div>
